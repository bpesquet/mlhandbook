# %% [markdown]
# <!--NAVIGATION-->
#
# <a href="https://colab.research.google.com/github/bpesquet/machine-learning-katas/blob/master/ml-algorithms/Linear_Regression.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Package setup

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [10, 8]
# %config InlineBackend.figure_format = 'retina'
import seaborn as sns
sns.set()
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Planar data

# %%
# Generate some linear-looking data
x = 10 * np.random.rand(50)
print(f"Data shape: {x.shape}")
y = 2 * x - 5 + np.random.randn(50)
print(f"Target shape: {y.shape}")
plt.scatter(x, y)
# Out:
# Data shape: (50,)
# Target shape: (50,)

# %%
# Create input matrix (2D array) with data on first axis
x_train = x[:, np.newaxis]
print(f"Training data shape: {X_train.shape}")
y_train = y

# Train a linear regressor on data
model = LinearRegression()
model.fit(x_train, y_train)

# Print slope and intercept values
print(f"Model slope: {model.coef_[0]:.5g}")
print(f"Model intercept: {model.intercept_:.5g}")
# Out:
# Training data shape: (50, 1)
# Model slope: 2.0176
# Model intercept: -5.0306

# %%
# Calculate MSE loss
y_pred = model.predict(x_train)
mse = mean_squared_error(y, y_pred)

# Plot best-fit line
x_fit = np.linspace(0, 10, 1000)
y_fit = model.predict(x_fit[:, np.newaxis])
plt.title(f"MSE: {mse:.5g}")
plt.scatter(x, y)
plt.plot(x_fit, y_fit, color='red')
